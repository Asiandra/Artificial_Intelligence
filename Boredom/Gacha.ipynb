# %%
import random

characters = {
    5: ['5-Star Hero A', '5-Star Hero B', '5-Star Hero C'],
    4: ['4-Star Hero D', '4-Star Hero E', '4-Star Hero F'],
    3: ['3-Star Hero G', '3-Star Hero H', '3-Star Hero I'],
    2: ['2-Star Hero J', '2-Star Hero K', '2-Star Hero L'],
    1: ['1-Star Hero M', '1-Star Hero N', '1-Star Hero O'],
}

rarity_probabilities = {
    5: 0.01,
    4: 0.05,
    3: 0.14,
    2: 0.30,
    1: 0.50
}

# Function to simulate a pull
def gacha_pull(pull_count=1, pity_counter=0, max_5_star_pity=90, max_4_star_pity=45):
    pulls = []
    for _ in range(pull_count):
        if pity_counter >= max_5_star_pity:
            rarity = 5
            character = random.choice(characters[rarity])
            pulls.append((rarity, character))
            pity_counter = 0
        elif pity_counter >= max_4_star_pity:
            rarity = 4
            character = random.choice(characters[rarity])
            pulls.append((rarity, character))
            pity_counter = 0
        else:
            rand = random.random()
            cumulative_probability = 0
            for rarity, prob in rarity_probabilities.items():
                cumulative_probability += prob
                if rand < cumulative_probability:
                    character = random.choice(characters[rarity])
                    pulls.append((rarity, character))
                    break
            pity_counter += 1

    return pulls, pity_counter


def simulate_gacha(pull_count, pity_counter):
    pulls, updated_pity_counter = gacha_pull(pull_count=pull_count, pity_counter=pity_counter)
    print(f"You got... {[(rarity, character) for rarity, character in pulls]}")
    print(f"Pity: {updated_pity_counter}")
    return pulls, updated_pity_counter


pity_counter = 0
pull_count = int(input("One pull for ten pull?\n"))

if pull_count == 1:
    pulls, pity_counter = simulate_gacha(1, pity_counter)
elif pull_count == 10:
    pulls, pity_counter = simulate_gacha(10, pity_counter)
else:
    print("Invalid input. Please enter 1 or 10.")
