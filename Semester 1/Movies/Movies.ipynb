# %%
import pandas as pd
import seaborn as sns
import requests

'''
url = 'https://api.themoviedb.org/3/movie/550?api_key=1c0cc47a066c76770c4506d3bf1169dd'
'''
# Out:
# "\nurl = 'https://api.themoviedb.org/3/movie/550?api_key=1c0cc47a066c76770c4506d3bf1169dd'\n"

# %%
url = "https://api.themoviedb.org/3/movie/now_playing?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
}

response = requests.get(url, headers=headers)
response = response.json()
now = pd.DataFrame(response["results"])
now.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg     [27, 18, 878]   933260
# 2  False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg      [28, 27, 53]  1029235
# 3  False  /eQEgKIRF7KeVGBQ8IYcklpU8RPf.jpg          [27, 53]  1034541
# 4  False  /3V4kLQg0kSqPLctI5ziYWabAZYF.jpg     [28, 878, 12]   912649
#
#   original_language         original_title  \
# 0                en         The Wild Robot
# 1                en          The Substance
# 2                en                 Azrael
# 3                en            Terrifier 3
# 4                en  Venom: The Last Dance
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    5200.959
# 1  Have you ever dreamt of a better version of yo...    3159.484
# 2  In a world where no one speaks, a devout femal...    1635.458
# 3  Five years after surviving Art the Clown's Hal...    1681.930
# 4  Eddie and Venom are on the run. Hunted by both...    1678.855
#
#                         poster_path release_date                  title  \
# 0  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12         The Wild Robot
# 1  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07          The Substance
# 2  /qpdFKDvJS7oLKTcBLXOaMwUESbs.jpg   2024-09-27                 Azrael
# 3  /63xYQj1BwRFielxsBDXvHIJyXVm.jpg   2024-10-09            Terrifier 3
# 4  /k42Owka8v91trK1qMYwCQCNwJKr.jpg   2024-10-22  Venom: The Last Dance
#
#    video  vote_average  vote_count
# 0  False         8.660        1284
# 1  False         7.300         797
# 2  False         6.095          84
# 3  False         7.044         103
# 4  False         7.300          19

# %%
response
# Out:
# {'dates': {'maximum': '2024-10-30', 'minimum': '2024-09-18'},
#  'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg',
#    'genre_ids': [16, 878, 10751],
#    'id': 1184918,
#    'original_language': 'en',
#    'original_title': 'The Wild Robot',
#    'overview': "After a shipwreck, an intelligent robot called Roz is stranded on an uninhabited island. To survive the harsh environment, Roz bonds with the island's animals and cares for an orphaned baby goose.",
#    'popularity': 5200.959,
#    'poster_path': '/wTnV3PCVW5O92JMrFvvrRcV39RU.jpg',
#    'release_date': '2024-09-12',
#    'title': 'The Wild Robot',
#    'video': False,
#    'vote_average': 8.66,
#    'vote_count': 1284},
#   {'adult': False,
#    'backdrop_path': '/7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg',
#    'genre_ids': [27, 18, 878],
#    'id': 933260,
#    'original_language': 'en',
#    'original_title': 'The Substance',
#    'overview': 'Have you ever dreamt of a better version of yourself? You, only better in every way. You should try this new product, it’s called The Substance. IT CHANGED MY LIFE. With The Substance, you can generate another you: younger, more beautiful, more perfect. You just have to share time – one week for one, one week for the other. A perfect balance of seven days each... Easy right? If you respect the balance... What could possibly go wrong?',
#    'popularity': 3159.484,
#    'poster_path': '/lqoMzCcZYEFK729d6qzt349fB4o.jpg',
#    'release_date': '2024-09-07',
#    'title': 'The Substance',
#    'video': False,
#    'vote_average': 7.3,
#    'vote_count': 797},
#   {'adult': False,
#    'backdrop_path': '/4KHEK6AQFHhv4TDtL3KLReePB05.jpg',
#    'genre_ids': [28, 27, 53],
#    'id': 1029235,
#    'original_language': 'en',
#    'original_title': 'Azrael',
#    'overview': 'In a world where no one speaks, a devout female hunts down a young woman who has escaped her imprisonment. Recaptured by its ruthless leaders, Azrael is due to be sacrificed to pacify an ancient evil deep within the surrounding wilderness.',
#    'popularity': 1635.458,
#    'poster_path': '/qpdFKDvJS7oLKTcBLXOaMwUESbs.jpg',
#    'release_date': '2024-09-27',
#    'title': 'Azrael',
#    'video': False,
#    'vote_average': 6.095,
#    'vote_count': 84},
#   {'adult': False,
#    'backdrop_path': '/eQEgKIRF7KeVGBQ8IYcklpU8RPf.jpg',
#    'genre_ids': [27, 53],
#    'id': 1034541,
#    'original_language': 'en',
#    'original_title': 'Terrifier 3',
#    'overview': "Five years after surviving Art the Clown's Halloween massacre, Sienna and Jonathan are still struggling to rebuild their shattered lives. As the holiday season approaches, they try to embrace the Christmas spirit and leave the horrors of the past behind. But just when they think they're safe, Art returns, determined to turn their holiday cheer into a new nightmare. The festive season quickly unravels as Art unleashes his twisted brand of terror, proving that no holiday is safe.",
#    'popularity': 1681.93,
#    'poster_path': '/63xYQj1BwRFielxsBDXvHIJyXVm.jpg',
#    'release_date': '2024-10-09',
#    'title': 'Terrifier 3',
#    'video': False,
#    'vote_average': 7.044,
#    'vote_count': 103},
#   {'adult': False,
#    'backdrop_path': '/3V4kLQg0kSqPLctI5ziYWabAZYF.jpg',
#    'genre_ids': [28, 878, 12],
#    'id': 912649,
#    'original_language': 'en',
#    'original_title': 'Venom: The Last Dance',
#    'overview': "Eddie and Venom are on the run. Hunted by both of their worlds and with the net closing in, the duo are forced into a devastating decision that will bring the curtains down on Venom and Eddie's last dance.",
#    'popularity': 1678.855,
#    'poster_path': '/k42Owka8v91trK1qMYwCQCNwJKr.jpg',
#    'release_date': '2024-10-22',
#    'title': 'Venom: The Last Dance',
#    'video': False,
#    'vote_average': 7.3,
#    'vote_count': 19},
#   {'adult': False,
#    'backdrop_path': '/xi1VSt3DtkevUmzCx2mNlCoDe74.jpg',
#    'genre_ids': [35, 14, 27],
#    'id': 917496,
#    'original_language': 'en',
#    'original_title': 'Beetlejuice Beetlejuice',
#    'overview': "After a family tragedy, three generations of the Deetz family return home to Winter River. Still haunted by Betelgeuse, Lydia's life is turned upside down when her teenage daughter, Astrid, accidentally opens the portal to the Afterlife.",
#    'popularity': 1352.254,
#    'poster_path': '/kKgQzkUCnQmeTPkyIwHly2t6ZFI.jpg',
#    'release_date': '2024-09-04',
#    'title': 'Beetlejuice Beetlejuice',
#    'video': False,
#    'vote_average': 7.208,
#    'vote_count': 1487},
#   {'adult': False,
#    'backdrop_path': '/g1z1ZvYKcmk9EnVOTYXR6vkNjkZ.jpg',
#    'genre_ids': [14, 27, 28],
#    'id': 1087822,
#    'original_language': 'en',
#    'original_title': 'Hellboy: The Crooked Man',
#    'overview': "Hellboy and a rookie BPRD agent get stranded in 1950s rural Appalachia. There, they discover a small community haunted by witches, led by a local devil with a troubling connection to Hellboy's past: the Crooked Man.",
#    'popularity': 1221.335,
#    'poster_path': '/iz2GabtToVB05gLTVSH7ZvFtsMM.jpg',
#    'release_date': '2024-08-29',
#    'title': 'Hellboy: The Crooked Man',
#    'video': False,
#    'vote_average': 5.0,
#    'vote_count': 145},
#   {'adult': False,
#    'backdrop_path': '/3m0j3hCS8kMAaP9El6Vy5Lqnyft.jpg',
#    'genre_ids': [878, 53, 27, 18],
#    'id': 1125510,
#    'original_language': 'es',
#    'original_title': 'El hoyo 2',
#    'overview': 'After a mysterious leader imposes his law in a brutal system of vertical cells, a new arrival battles against a dubious food distribution method.',
#    'popularity': 1091.003,
#    'poster_path': '/izuzUb0sDokqp9o8utVfsrSJuy5.jpg',
#    'release_date': '2024-09-27',
#    'title': 'The Platform 2',
#    'video': False,
#    'vote_average': 5.7,
#    'vote_count': 668},
#   {'adult': False,
#    'backdrop_path': '/64tinBsds1nVp4wOCgYhMbSgsRW.jpg',
#    'genre_ids': [28, 18, 36],
#    'id': 1075676,
#    'original_language': 'ko',
#    'original_title': '전,란',
#    'overview': 'In the Joseon Dynasty, two friends who grew up together — one the master and one the servant — reunite post-war as enemies on opposing sides.',
#    'popularity': 954.411,
#    'poster_path': '/hg9OeaCRSpazrfqYyEFr6BDaZW8.jpg',
#    'release_date': '2024-10-02',
#    'title': 'Uprising',
#    'video': False,
#    'vote_average': 7.4,
#    'vote_count': 65},
#   {'adult': False,
#    'backdrop_path': '/of1tQasFGCeHgWPmSgdA1WS6hNW.jpg',
#    'genre_ids': [80, 53, 28],
#    'id': 1047373,
#    'original_language': 'en',
#    'original_title': 'The Silent Hour',
#    'overview': 'While working a case as an interpreter, a hearing-impaired police detective must confront a group of criminals trying to eliminate a deaf murder witness in her apartment building.',
#    'popularity': 808.001,
#    'poster_path': '/j736cRzBtEPCm0nHnpRN1prqiqj.jpg',
#    'release_date': '2024-10-03',
#    'title': 'The Silent Hour',
#    'video': False,
#    'vote_average': 6.603,
#    'vote_count': 29},
#   {'adult': False,
#    'backdrop_path': '/reNf6GBzOe48l9WEnFOxXgW56Vg.jpg',
#    'genre_ids': [18, 80, 53],
#    'id': 889737,
#    'original_language': 'en',
#    'original_title': 'Joker: Folie à Deux',
#    'overview': "While struggling with his dual identity, Arthur Fleck not only stumbles upon true love, but also finds the music that's always been inside him.",
#    'popularity': 660.691,
#    'poster_path': '/aciP8Km0waTLXEYf5ybFK5CSUxl.jpg',
#    'release_date': '2024-10-01',
#    'title': 'Joker: Folie à Deux',
#    'video': False,
#    'vote_average': 5.8,
#    'vote_count': 908},
#   {'adult': False,
#    'backdrop_path': '/l8OyAXEp5FKZWmDhqJMbiwAEvz.jpg',
#    'genre_ids': [27, 18],
#    'id': 814889,
#    'original_language': 'en',
#    'original_title': 'Never Let Go',
#    'overview': 'As an evil takes over the world beyond their front doorstep, the only protection for a mother and her twin sons is their house and their family’s protective bond.',
#    'popularity': 595.504,
#    'poster_path': '/3EpZ2ksjijmdr8BhISP03PYzNFW.jpg',
#    'release_date': '2024-09-18',
#    'title': 'Never Let Go',
#    'video': False,
#    'vote_average': 6.134,
#    'vote_count': 142},
#   {'adult': False,
#    'backdrop_path': '/cVg97LOJgrDZJ7bVmjU2KsGRYnU.jpg',
#    'genre_ids': [27, 9648],
#    'id': 1100782,
#    'original_language': 'en',
#    'original_title': 'Smile 2',
#    'overview': 'About to embark on a new world tour, global pop sensation Skye Riley begins experiencing increasingly terrifying and inexplicable events. Overwhelmed by the escalating horrors and the pressures of fame, Skye is forced to face her dark past to regain control of her life before it spirals out of control.',
#    'popularity': 741.034,
#    'poster_path': '/aE85MnPIsSoSs3978Noo16BRsKN.jpg',
#    'release_date': '2024-10-16',
#    'title': 'Smile 2',
#    'video': False,
#    'vote_average': 7.1,
#    'vote_count': 123},
#   {'adult': False,
#    'backdrop_path': '/aFDYcmwEWRiEh58Ri1tMpCUWPBp.jpg',
#    'genre_ids': [10770, 10751, 35, 27, 16],
#    'id': 1354627,
#    'original_language': 'en',
#    'original_title': 'SpongeBob Squarepants: Kreepaway Kamp',
#    'overview': 'While at Kamp Koral for a reunion, SpongeBob and the gang are stalked by a mysterious figure lurking in the shadows as campers start disappearing one by one!',
#    'popularity': 574.222,
#    'poster_path': '/blRsgsexoBqnjcEJkV8beKAVT6J.jpg',
#    'release_date': '2024-10-10',
#    'title': 'SpongeBob Squarepants: Kreepaway Kamp',
#    'video': False,
#    'vote_average': 7.4,
#    'vote_count': 23},
#   {'adult': False,
#    'backdrop_path': '/zAqBIeO71BFL7bAtP5TFzVjVamy.jpg',
#    'genre_ids': [10749, 18],
#    'id': 1079091,
#    'original_language': 'en',
#    'original_title': 'It Ends with Us',
#    'overview': "When a woman's first love suddenly reenters her life, her relationship with a charming, but abusive neurosurgeon is upended, and she realizes she must learn to rely on her own strength to make an impossible choice for her future.",
#    'popularity': 799.043,
#    'poster_path': '/AjV6jFJ2YFIluYo4GQf13AA1tqu.jpg',
#    'release_date': '2024-08-07',
#    'title': 'It Ends with Us',
#    'video': False,
#    'vote_average': 7.178,
#    'vote_count': 863},
#   {'adult': False,
#    'backdrop_path': '/z8muwOfNZ4qivqgASnIkeeHSSX3.jpg',
#    'genre_ids': [27],
#    'id': 1089123,
#    'original_language': 'en',
#    'original_title': "Daddy's Head",
#    'overview': "A boy and his stepmother fear for their safety after an eerie creature resembling the boy's recently deceased father visits them.",
#    'popularity': 590.599,
#    'poster_path': '/nEWbEBs8BalwasA4Un8rll3kauT.jpg',
#    'release_date': '2024-10-10',
#    'title': "Daddy's Head",
#    'video': False,
#    'vote_average': 5.7,
#    'vote_count': 26},
#   {'adult': False,
#    'backdrop_path': '/cRdA9xjHBbobw4LJFsQ3j1CgpVq.jpg',
#    'genre_ids': [27, 53],
#    'id': 663712,
#    'original_language': 'en',
#    'original_title': 'Terrifier 2',
#    'overview': "A year after the Miles County massacre, Art the Clown is resurrected by a sinister entity. Art returns home, where he must hunt down and destroy teenage Sienna and her younger brother Jonathan on Halloween. As the body count rises, the siblings fight to stay alive while uncovering the true nature of Art's evil intent.",
#    'popularity': 469.204,
#    'poster_path': '/8gLhu8UFPZfH2Hv11JhTZkb9CVl.jpg',
#    'release_date': '2022-10-06',
#    'title': 'Terrifier 2',
#    'video': False,
#    'vote_average': 6.771,
#    'vote_count': 1863},
#   {'adult': False,
#    'backdrop_path': '/b3mdmjYTEL70j7nuXATUAD9qgu4.jpg',
#    'genre_ids': [16, 14, 12],
#    'id': 823219,
#    'original_language': 'xx',
#    'original_title': 'Flow',
#    'overview': 'The world seems to be coming to an end, teeming with the vestiges of a human presence. Cat is a solitary animal, but as its home is devastated by a great flood, he finds refuge on a boat populated by various species, and will have to team up with them despite their differences. In the lonesome boat sailing through mystical overflowed landscapes, they navigate the challenges and dangers of adapting to this new world.',
#    'popularity': 572.059,
#    'poster_path': '/dzDMewC0Hwv01SROiWgKOi4iOc1.jpg',
#    'release_date': '2024-08-30',
#    'title': 'Flow',
#    'video': False,
#    'vote_average': 8.9,
#    'vote_count': 113},
#   {'adult': False,
#    'backdrop_path': '/1fL2S8LKxCVE9KoPRBXeagmBtex.jpg',
#    'genre_ids': [27, 53],
#    'id': 1114513,
#    'original_language': 'en',
#    'original_title': 'Speak No Evil',
#    'overview': 'When an American family is invited to spend the weekend at the idyllic country estate of a charming British family they befriended on vacation, what begins as a dream holiday soon warps into a snarled psychological nightmare.',
#    'popularity': 408.105,
#    'poster_path': '/fDtkrO2OAF8LKQTdzYmu1Y7lCLB.jpg',
#    'release_date': '2024-09-11',
#    'title': 'Speak No Evil',
#    'video': False,
#    'vote_average': 7.353,
#    'vote_count': 730},
#   {'adult': False,
#    'backdrop_path': '/vGaBqgY8YRzQVUbBMPnd5SmYvL7.jpg',
#    'genre_ids': [16, 35],
#    'id': 1329336,
#    'original_language': 'en',
#    'original_title': 'The Bad Guys: Haunted Heist',
#    'overview': 'The crafty Bad Guys crew embarks on a high-stakes Halloween heist to swipe a priceless amulet from a spooky mansion. What could go wrong?',
#    'popularity': 409.774,
#    'poster_path': '/oEJC05CqPugMxC4rFu9r6r6vg6m.jpg',
#    'release_date': '2024-10-02',
#    'title': 'The Bad Guys: Haunted Heist',
#    'video': False,
#    'vote_average': 7.3,
#    'vote_count': 65}],
#  'total_pages': 280,
#  'total_results': 5583}

# %%
# Popular

url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
}

response = requests.get(url, headers=headers)
response = response.json()
pop = pd.DataFrame(response["results"])

# %%
# Top Rated

url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
}

response = requests.get(url, headers=headers)
response = response.json()
top = pd.DataFrame(response["results"])

# %%
# Upcoming
url = "https://api.themoviedb.org/3/movie/upcoming?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
}

response = requests.get(url, headers=headers)
response = response.json()
up = pd.DataFrame(response["results"])

# %%
df = pd.concat([now, pop, top, up])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80 entries, 0 to 19
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              80 non-null     bool
#  1   backdrop_path      80 non-null     object
#  2   genre_ids          80 non-null     object
#  3   id                 80 non-null     int64
#  4   original_language  80 non-null     object
#  5   original_title     80 non-null     object
#  6   overview           80 non-null     object
#  7   popularity         80 non-null     float64
#  8   poster_path        80 non-null     object
#  9   release_date       80 non-null     object
#  10  title              80 non-null     object
#  11  video              80 non-null     bool
#  12  vote_average       80 non-null     float64
#  13  vote_count         80 non-null     int64
# dtypes: bool(2), float64(2), int64(2), object(8)
# memory usage: 8.3+ KB

# %%
df.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg     [27, 18, 878]   933260
# 2  False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg      [28, 27, 53]  1029235
# 3  False  /eQEgKIRF7KeVGBQ8IYcklpU8RPf.jpg          [27, 53]  1034541
# 4  False  /3V4kLQg0kSqPLctI5ziYWabAZYF.jpg     [28, 878, 12]   912649
#
#   original_language         original_title  \
# 0                en         The Wild Robot
# 1                en          The Substance
# 2                en                 Azrael
# 3                en            Terrifier 3
# 4                en  Venom: The Last Dance
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    5200.959
# 1  Have you ever dreamt of a better version of yo...    3159.484
# 2  In a world where no one speaks, a devout femal...    1635.458
# 3  Five years after surviving Art the Clown's Hal...    1681.930
# 4  Eddie and Venom are on the run. Hunted by both...    1678.855
#
#                         poster_path release_date                  title  \
# 0  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12         The Wild Robot
# 1  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07          The Substance
# 2  /qpdFKDvJS7oLKTcBLXOaMwUESbs.jpg   2024-09-27                 Azrael
# 3  /63xYQj1BwRFielxsBDXvHIJyXVm.jpg   2024-10-09            Terrifier 3
# 4  /k42Owka8v91trK1qMYwCQCNwJKr.jpg   2024-10-22  Venom: The Last Dance
#
#    video  vote_average  vote_count
# 0  False         8.660        1284
# 1  False         7.300         797
# 2  False         6.095          84
# 3  False         7.044         103
# 4  False         7.300          19

# %%
df.drop_duplicates(subset=['id'], inplace=True)

# %%
def get_revenue_budget(df):
    data = {
        "id":[],
        "budget": [],
        "revenue": []
    }

    for i in df["id"]:
        data["id"].append(i)
        url = "https://api.themoviedb.org/3/movie/"+str(i)+"?language=en-US"

        headers = {
            "accept": "application/json",
            "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
        }

        response = requests.get(url, headers=headers)
        response = response.json()
        data["budget"].append(response["budget"])
        data["revenue"].append(response["revenue"])
        
    return pd.DataFrame(data)

# %%
money_df = get_revenue_budget(df)
money_df.head()
# Out:
#         id     budget    revenue
# 0  1184918   78000000  197296880
# 1   933260   17500000   29106531
# 2  1029235   12000000          0
# 3  1034541    2000000   41643487
# 4   912649  110000000          0

# %%
df = pd.merge(df, money_df, how="inner", on="id")
df.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg     [27, 18, 878]   933260
# 2  False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg      [28, 27, 53]  1029235
# 3  False  /eQEgKIRF7KeVGBQ8IYcklpU8RPf.jpg          [27, 53]  1034541
# 4  False  /3V4kLQg0kSqPLctI5ziYWabAZYF.jpg     [28, 878, 12]   912649
#
#   original_language         original_title  \
# 0                en         The Wild Robot
# 1                en          The Substance
# 2                en                 Azrael
# 3                en            Terrifier 3
# 4                en  Venom: The Last Dance
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    5200.959
# 1  Have you ever dreamt of a better version of yo...    3159.484
# 2  In a world where no one speaks, a devout femal...    1635.458
# 3  Five years after surviving Art the Clown's Hal...    1681.930
# 4  Eddie and Venom are on the run. Hunted by both...    1678.855
#
#                         poster_path release_date                  title  \
# 0  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12         The Wild Robot
# 1  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07          The Substance
# 2  /qpdFKDvJS7oLKTcBLXOaMwUESbs.jpg   2024-09-27                 Azrael
# 3  /63xYQj1BwRFielxsBDXvHIJyXVm.jpg   2024-10-09            Terrifier 3
# 4  /k42Owka8v91trK1qMYwCQCNwJKr.jpg   2024-10-22  Venom: The Last Dance
#
#    video  vote_average  vote_count     budget    revenue
# 0  False         8.660        1284   78000000  197296880
# 1  False         7.300         797   17500000   29106531
# 2  False         6.095          84   12000000          0
# 3  False         7.044         103    2000000   41643487
# 4  False         7.300          19  110000000          0

# %%
sns.regplot(data=df, x="budget", y="revenue")
# Out:
# <AxesSubplot:xlabel='budget', ylabel='revenue'>

# %%
import numpy as np
df["revenue_sqrt"] = np.sqrt(df["revenue"])
df["budget_sqrt"] = np.sqrt(df["budget"])
df.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg     [27, 18, 878]   933260
# 2  False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg      [28, 27, 53]  1029235
# 3  False  /eQEgKIRF7KeVGBQ8IYcklpU8RPf.jpg          [27, 53]  1034541
# 4  False  /3V4kLQg0kSqPLctI5ziYWabAZYF.jpg     [28, 878, 12]   912649
#
#   original_language         original_title  \
# 0                en         The Wild Robot
# 1                en          The Substance
# 2                en                 Azrael
# 3                en            Terrifier 3
# 4                en  Venom: The Last Dance
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    5200.959
# 1  Have you ever dreamt of a better version of yo...    3159.484
# 2  In a world where no one speaks, a devout femal...    1635.458
# 3  Five years after surviving Art the Clown's Hal...    1681.930
# 4  Eddie and Venom are on the run. Hunted by both...    1678.855
#
#                         poster_path release_date                  title  \
# 0  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12         The Wild Robot
# 1  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07          The Substance
# 2  /qpdFKDvJS7oLKTcBLXOaMwUESbs.jpg   2024-09-27                 Azrael
# 3  /63xYQj1BwRFielxsBDXvHIJyXVm.jpg   2024-10-09            Terrifier 3
# 4  /k42Owka8v91trK1qMYwCQCNwJKr.jpg   2024-10-22  Venom: The Last Dance
#
#    video  vote_average  vote_count     budget    revenue  revenue_sqrt  \
# 0  False         8.660        1284   78000000  197296880  14046.240778
# 1  False         7.300         797   17500000   29106531   5395.046895
# 2  False         6.095          84   12000000          0      0.000000
# 3  False         7.044         103    2000000   41643487   6453.176505
# 4  False         7.300          19  110000000          0      0.000000
#
#     budget_sqrt
# 0   8831.760866
# 1   4183.300133
# 2   3464.101615
# 3   1414.213562
# 4  10488.088482

# %%
def best_fit(data, x, y):
    m = 0
    for count in range(100):
        m = m + 1
        b = 0
        res = 0
        for i in range(len(data)):
            pred_y = (m * data.loc[i][x]) + b
            act_y = data.loc[i][y]
            temp = act_y - pred_y 
            temp = temp ** 2
            res = res + temp
        print(res)
    return (m, b, res)

best_fit(df, "budget_sqrt", "revenue_sqrt")
# Out:
# 5239105482.848893
# 3812502248.6977873
# 6705250516.54668
# 13917350286.395573
# 25448801558.244473
# 41299604332.09336
# 61469758607.94225
# 85959264385.79115
# 114768121665.64005
# 147896330447.48892
# 185343890731.33783
# 227110802517.1867
# 273197065805.0356
# 323602680594.8845
# 378327646886.7334
# 437371964680.58246
# 500735633976.43115
# 568418654774.28
# 640421027074.1289
# 716742750875.9777
# 797383826179.8269
# 882344252985.6754
# 971624031293.5248
# 1065223161103.3734
# 1163141642415.222
# 1265379475229.0713
# 1371936659544.9202
# 1482813195362.769
# 1598009082682.618
# 1717524321504.4663
# 1841358911828.3154
# 1969512853654.1643
# 2101986146982.0134
# 2238778791811.863
# 2379890788143.712
# 2525322135977.5605
# 2675072835313.409
# 2829142886151.258
# 2987532288491.107
# 3150241042332.956
# 3317269147676.804
# 3488616604522.6533
# 3664283412870.5024
# 3844269572720.352
# 4028575084072.199
# 4217199946926.049
# 4410144161281.898
# 4607407727139.746
# 4808990644499.597
# 5014892913361.445
# 5225114533725.293
# 5439655505591.142
# 5658515828958.993
# 5881695503828.84
# 6109194530200.689
# 6341012908074.539
# 6577150637450.389
# 6817607718328.233
# 7062384150708.086
# 7311479934589.935
# 7564895069973.783
# 7822629556859.629
# 8084683395247.48
# 8351056585137.329
# 8621749126529.179
# 8896761019423.027
# 9176092263818.877
# 9459742859716.725
# 9747712807116.57
# 10040002106018.424
# 10336610756422.27
# 10637538758328.12
# 10942786111735.967
# 11252352816645.812
# 11566238873057.672
# 11884444280971.516
# 12206969040387.365
# 12533813151305.215
# 12864976613725.064
# 13200459427646.908
# 13540261593070.762
# 13884383109996.61
# 14232823978424.457
# 14585584198354.305
# 14942663769786.156
# 15304062692720.006
# 15669780967155.857
# 16039818593093.701
# 16414175570533.555
# 16792851899475.396
# 17175847579919.25
# 17563162611865.096
# 17954796995312.94
# 18350750730262.793
# 18751023816714.65
# 19155616254668.492
# 19564528044124.34
# 19977759185082.19
# 20395309677542.04
# 20817179521503.89
# (100, 0, 20817179521503.89)

# %%
def get_r2(df, x, y, m, b):
    mean = df[y].mean()
    total_sst = 0
    for value in df[y]:
        difference = (value - mean)
        squared = difference ** 2
        total_sst += squared
    
    total_ssr = 0
    for i in range(len(df)):
        predicted = (m * df.loc[i][x]) + b
        difference = predicted - df.loc[i][y]
        squared = difference ** 2
        total_ssr += squared
    
    r2 = 1 - (total_ssr / total_sst)
    return r2

get_r2(df, "budget", "revenue", 1.896, 1028.934)
# Out:
# 0.18038445643262735

# %%
action = []
romance = []

url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=" + str(page)
    
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIxYzBjYzQ3YTA2NmM3Njc3MGM0NTA2ZDNiZjExNjlkZCIsIm5iZiI6MTcyOTY5NzE5My41MDc4ODcsInN1YiI6IjY2ZmViNWZjZjg3OGFkZmVkMDg0ZjFhYSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.k9hfQzInRObDtU3puS3rcAtgzpvOI0dzgnsYSAfCbcs"
}
response = requests.get(url, headers=headers)
response = response.json()["results"]
for i in range(len(response)):
    genres = response[i]["genre_ids"]
    if 28 in genres:
        action.append(response[i])
    if 10749 in genres:
        romance.append(response[i])
action = pd.DataFrame(action)
romance = pd.DataFrame(romance)
print(len(action), len(romance))
# Out:
# 6 3

# %%
page = 2
while len(action) < 100 or len(romance) < 100:
    url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=" + str(page)
    
    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIxYzBjYzQ3YTA2NmM3Njc3MGM0NTA2ZDNiZjExNjlkZCIsIm5iZiI6MTcyOTY5NzE5My41MDc4ODcsInN1YiI6IjY2ZmViNWZjZjg3OGFkZmVkMDg0ZjFhYSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.k9hfQzInRObDtU3puS3rcAtgzpvOI0dzgnsYSAfCbcs"
    }
    response = requests.get(url, headers=headers)
    response = response.json()["results"]
    page += 1
    for i in range(len(response)):
        genres = response[i]["genre_ids"]
        temp = pd.DataFrame(response[i])
        if 28 in genres:
            action = pd.concat([temp, action], ignore_index=True)
        if 10749 in genres:
            romance = pd.concat([temp, romance], ignore_index=True)
            
print(len(action), len(romance))
action = action[:100]
romance = romance[:100]
# Out:
# 356 104

# %%
print(len(action), len(romance))
# Out:
# 100 100

# %%
url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=1"
    
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIxYzBjYzQ3YTA2NmM3Njc3MGM0NTA2ZDNiZjExNjlkZCIsIm5iZiI6MTcyOTY5NzE5My41MDc4ODcsInN1YiI6IjY2ZmViNWZjZjg3OGFkZmVkMDg0ZjFhYSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.k9hfQzInRObDtU3puS3rcAtgzpvOI0dzgnsYSAfCbcs"
}

response = requests.get(url, headers=headers)
response = response.json()
now = pd.DataFrame(response["results"])
now.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /9SSEUrSqhljBMzRe4aBTh17rUaC.jpg         [878, 27]   945961
# 2  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg     [27, 18, 878]   933260
# 3  False  /yDHYTfA3R0jFYba16jBB1ef8oIt.jpg     [28, 35, 878]   533535
# 4  False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg      [28, 27, 53]  1029235
#
#   original_language        original_title  \
# 0                en        The Wild Robot
# 1                en        Alien: Romulus
# 2                en         The Substance
# 3                en  Deadpool & Wolverine
# 4                en                Azrael
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    5200.959
# 1  While scavenging the deep ends of a derelict s...    3904.571
# 2  A fading celebrity decides to usea black marke...    3159.484
# 3  A listless Wade Wilson toils away in civilian ...    2203.301
# 4  In a world where no one speaks, a devout femal...    1635.458
#
#                         poster_path release_date                 title  video  \
# 0  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12        The Wild Robot  False
# 1  /b33nnKl1GSFbao4l3fZDDqsMx0F.jpg   2024-08-13        Alien: Romulus  False
# 2  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07         The Substance  False
# 3  /8cdWjvZQUExUUTzyp4t6EDMubfO.jpg   2024-07-24  Deadpool & Wolverine  False
# 4  /qpdFKDvJS7oLKTcBLXOaMwUESbs.jpg   2024-09-27                Azrael  False
#
#    vote_average  vote_count
# 0         8.661        1288
# 1         7.300        1807
# 2         7.321         803
# 3         7.712        4723
# 4         6.095          84

# %% [markdown]
# <span style="font-family: Georgia; font-size: 20px; color: blue; text-align: center;">How do the amount of votes for action and romance movies change based on the popularity?</span>
