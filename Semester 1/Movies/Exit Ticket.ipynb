# %%
import pandas as pd
import seaborn as sns

em = pd.read_json("english_movies.json")
em.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              730 non-null    bool
#  1   backdrop_path      730 non-null    object
#  2   genre_ids          730 non-null    int64
#  3   id                 730 non-null    int64
#  4   original_language  730 non-null    object
#  5   original_title     730 non-null    object
#  6   overview           730 non-null    object
#  7   popularity         730 non-null    float64
#  8   poster_path        730 non-null    object
#  9   release_date       730 non-null    object
#  10  title              730 non-null    object
#  11  video              730 non-null    bool
#  12  vote_average       730 non-null    float64
#  13  vote_count         730 non-null    int64
#  14  budget             730 non-null    int64
#  15  revenue            730 non-null    int64
# ...

# %%
fm = pd.read_json("french_movies.json")
fm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 692 entries, 0 to 691
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              692 non-null    bool
#  1   backdrop_path      692 non-null    object
#  2   genre_ids          692 non-null    int64
#  3   id                 692 non-null    int64
#  4   original_language  692 non-null    object
#  5   original_title     692 non-null    object
#  6   overview           692 non-null    object
#  7   popularity         692 non-null    float64
#  8   poster_path        692 non-null    object
#  9   release_date       692 non-null    object
#  10  title              692 non-null    object
#  11  video              692 non-null    bool
#  12  vote_average       692 non-null    float64
#  13  vote_count         692 non-null    int64
#  14  budget             692 non-null    int64
#  15  revenue            692 non-null    int64
# ...

# %%
em.head()
# Out:
#    adult                     backdrop_path  genre_ids       id  \
# 0  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg         18      278
# 1  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg         18      278
# 2  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg         80      278
# 3  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg         80      278
# 4  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg         16  1184918
#
#   original_language            original_title  \
# 0                en  The Shawshank Redemption
# 1                en  The Shawshank Redemption
# 2                en  The Shawshank Redemption
# 3                en  The Shawshank Redemption
# 4                en            The Wild Robot
#
#                                             overview  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...     230.813
# 1  Imprisoned in the 1940s for the double murder ...     230.813
# 2  Imprisoned in the 1940s for the double murder ...     230.813
# ...

# %%
fm.head()
# Out:
#    adult                     backdrop_path  genre_ids       id  \
# 0  False  /i9qxG4UVgfX4AdMGnfRzMYEowLQ.jpg         12  1084736
# 1  False  /i9qxG4UVgfX4AdMGnfRzMYEowLQ.jpg         12  1084736
# 2  False  /i9qxG4UVgfX4AdMGnfRzMYEowLQ.jpg         12  1084736
# 3  False  /i9qxG4UVgfX4AdMGnfRzMYEowLQ.jpg         12  1084736
# 4  False  /i9qxG4UVgfX4AdMGnfRzMYEowLQ.jpg         12  1084736
#
#   original_language            original_title  \
# 0                fr  Le Comte de Monte-Cristo
# 1                fr  Le Comte de Monte-Cristo
# 2                fr  Le Comte de Monte-Cristo
# 3                fr  Le Comte de Monte-Cristo
# 4                fr  Le Comte de Monte-Cristo
#
#                                             overview  popularity  \
# 0  Edmond Dantes becomes the target of a sinister...     170.237
# 1  Edmond Dantes becomes the target of a sinister...     170.237
# 2  Edmond Dantes becomes the target of a sinister...     170.237
# ...

# %%
sns.regplot(data=em, x="budget", y="popularity")
sns.regplot(data=fm, x="budget", y="popularity")
# Out:
# <Axes: xlabel='budget', ylabel='popularity'>

# %%
import numpy as np
em["popularity_sqrt"] = np.sqrt(em["popularity"])
em["budget_sqrt"] = np.sqrt(em["budget"])
em.head()
# Out:
#    adult                     backdrop_path  genre_ids       id  \
# 0  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg         18      278
# 1  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg         18      278
# 2  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg         80      278
# 3  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg         80      278
# 4  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg         16  1184918
#
#   original_language            original_title  \
# 0                en  The Shawshank Redemption
# 1                en  The Shawshank Redemption
# 2                en  The Shawshank Redemption
# 3                en  The Shawshank Redemption
# 4                en            The Wild Robot
#
#                                             overview  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...     230.813
# 1  Imprisoned in the 1940s for the double murder ...     230.813
# 2  Imprisoned in the 1940s for the double murder ...     230.813
# ...

# %%
fm["popularity_sqrt"] = np.sqrt(fm["popularity"])
fm["budget_sqrt"] = np.sqrt(fm["budget"])
fm.head()
# Out:
#    adult                     backdrop_path  genre_ids       id  \
# 0  False  /i9qxG4UVgfX4AdMGnfRzMYEowLQ.jpg         12  1084736
# 1  False  /i9qxG4UVgfX4AdMGnfRzMYEowLQ.jpg         12  1084736
# 2  False  /i9qxG4UVgfX4AdMGnfRzMYEowLQ.jpg         12  1084736
# 3  False  /i9qxG4UVgfX4AdMGnfRzMYEowLQ.jpg         12  1084736
# 4  False  /i9qxG4UVgfX4AdMGnfRzMYEowLQ.jpg         12  1084736
#
#   original_language            original_title  \
# 0                fr  Le Comte de Monte-Cristo
# 1                fr  Le Comte de Monte-Cristo
# 2                fr  Le Comte de Monte-Cristo
# 3                fr  Le Comte de Monte-Cristo
# 4                fr  Le Comte de Monte-Cristo
#
#                                             overview  popularity  \
# 0  Edmond Dantes becomes the target of a sinister...     170.237
# 1  Edmond Dantes becomes the target of a sinister...     170.237
# 2  Edmond Dantes becomes the target of a sinister...     170.237
# ...

# %%
sns.regplot(data=em, x="budget_sqrt", y="popularity_sqrt")
sns.regplot(data=fm, x="budget_sqrt", y="popularity_sqrt")
# Out:
# <Axes: xlabel='budget_sqrt', ylabel='popularity_sqrt'>

# %%
em['popularity'].max()
# Out:
# 6191.489

# %%
threshold = 6191
em_filtered = em[em['popularity'] < threshold]

# %%
sns.regplot(data=em_filtered, x="budget", y="popularity")
sns.regplot(data=fm, x="budget", y="popularity")
# Out:
# <Axes: xlabel='budget', ylabel='popularity'>

# %%
em['popularity_sqrt'].max()
# Out:
# 78.68601527590528

# %%
tree = 78.68601527590528
em_filtered = em[em['popularity_sqrt'] < tree]

# %%
sns.regplot(data=em_filtered, x="budget_sqrt", y="popularity_sqrt")
sns.regplot(data=fm, x="budget_sqrt", y="popularity_sqrt")
# Out:
# <Axes: xlabel='budget_sqrt', ylabel='popularity_sqrt'>

# %%
fm['popularity_sqrt'].max()
# Out:
# 13.047490180107436

# %%
yahoo = 13.047490180107436
fm_filtered = fm[fm['popularity_sqrt'] < yahoo]

# %%
sns.regplot(data=em_filtered, x="budget_sqrt", y="popularity_sqrt")
sns.regplot(data=fm_filtered, x="budget_sqrt", y="popularity_sqrt")
# Out:
# <Axes: xlabel='budget_sqrt', ylabel='popularity_sqrt'>

# %% [markdown]
# <span style="color: purple; font-size: 15px;">The regresion line for English movies, blue, have a steeper slope than the French movies, orange,  showing that the budget for English movies have a signnificantly higher impact on the popularity of movies in English than French. A lot of French movies have a low budget, which give them a lower popularity score compared to the one movie with a higher buget, but still lower popularity score than most of the English movies with around the same budget.</span>

# %%
sns.regplot(data=em, x="revenue", y="popularity", color="blue")
sns.regplot(data=fm, x="revenue", y="popularity", color="purple")
# Out:
# <Axes: xlabel='revenue', ylabel='popularity'>

# %%
em['popularity'].max()
# Out:
# 6191.489

# %%
enasaki = 6191.489
em_enasaki = em[em['popularity'] < enasaki]

# %%
sns.regplot(data=em_enasaki, x="revenue", y="popularity", color="brown")
sns.regplot(data=fm, x="revenue", y="popularity", color="yellow")
# Out:
# <Axes: xlabel='revenue', ylabel='popularity'>

# %%
correlationes=em['revenue'].corr(em['popularity'])
correlationes
# Out:
# 0.04519017465970568

# %%
correlationesf=fm['revenue'].corr(fm['popularity'])
correlationesf
# Out:
# 0.39769567191795874
